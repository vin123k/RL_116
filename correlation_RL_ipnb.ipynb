# %% [markdown]
# <a href="https://colab.research.google.com/github/vin123k/RL_116/blob/main/correlation_RL_ipnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x = np.random.randint(0,50,1000)
x
# Out:
# array([37, 43, 12,  8,  9, 11,  5, 15,  0, 16,  1, 12,  7, 45,  6, 25, 20,
#        37, 18, 20, 11, 42, 28, 29, 14,  4, 23, 23, 41, 49, 30, 32, 22, 13,
#        41,  9,  7, 22,  1,  0, 17,  8, 24, 13, 47, 42,  8, 30,  7,  3,  6,
#        21, 49,  3,  4, 24, 49, 43, 12, 26, 16, 45, 41, 18, 15,  0,  4, 25,
#        47, 34, 23,  7, 26, 25, 40, 22,  9,  3, 39, 23, 36, 27, 37, 19, 38,
#         8, 32, 34, 10, 23, 15, 47, 23, 25,  7, 28, 10, 46, 32, 24, 23,  1,
#        49, 13,  3,  0, 13,  6, 21,  6,  2, 12, 27, 21, 11,  7, 13,  8, 11,
#        12, 43, 20, 30, 36, 39,  7, 45,  4, 48, 18, 32, 13, 10, 23, 17,  7,
#        24, 10, 28, 20, 32, 12,  1, 30, 41, 24, 18, 33,  2, 44, 28, 39, 34,
#        10, 32, 41, 18, 22,  6,  2,  7, 39, 48, 15,  5, 17, 42, 20, 48, 22,
#        37, 13, 49, 33, 20, 10, 32, 25, 21, 39, 32, 19, 25, 49, 14, 13, 20,
#        43,  6, 13, 15, 24,  9,  2,  7,  5, 36, 37, 21, 40, 13, 27, 49, 49,
# ...

# %%
y = x + np.random.normal(0,10,1000)

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
# positive direction
plt.scatter(x,y)
plt.show()

# %%
y = x - np.random.normal(0,10,1000)

# %%
# positive direction
plt.scatter(x,y)
plt.show()

# %%
y = 100 - x + np.random.normal(0,5,1000)

np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.94110977],
#        [-0.94110977,  1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
x = np.random.randint(0,50,1000)
y = x + np.random.randint(0,33,1000)
z = 100 - x + np.random.randint(0,50,1000)

# %%
plt.scatter(y,z)
plt.show()

# %%
plt.scatter(x,z)
plt.show()

# %%
x = np.random.randint(0,50,1000)
y = np.random.randint(0,50,1000)

np.corrcoef(x,y)
# Out:
# array([[1.        , 0.02346027],
#        [0.02346027, 1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.normal(0, 10 , 1000)
df['c'] = 100 - df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.823670 -0.943788  0.017709
# b  0.823670  1.000000 -0.772296 -0.023555
# c -0.943788 -0.772296  1.000000 -0.021769
# d  0.017709 -0.023555 -0.021769  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
